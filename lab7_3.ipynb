# %% [markdown]
# # Lab 7: Versioning 3
#
# Before making any changes to these files, please create a new branch to work on and give it the same name as your Github username. This will be used to determine if you have completed the task successfully.
#
# In the file directory there is a file called `icecream.csv`. There are four columns.
# The first column consists of the Github usernames of the people in the class. The next columns are empty and represent the persons favourite ice cream flavour, favourite colour and height in cm. The code below will read this file and produce graphs showing summaries of the class.
#
# Find your username and fill out your row in `icecream.csv`
# To keep the code simple, you may choose between the following:
#
# **Check if you have entered your row correctly by running the plots below.**
#
# As there is only one entry, you will not see much, you can generate a test dataset if you want to see how it looks like.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv("icecream.csv")

# Create new row with details
data = data[data["Github"] != "Mairah27"]
new_row = {
    "Github": "Mairah27",
    "Favourite Ice Cream": "matcha latte",
    "Favourite Colour": "pink",
    "Height (cm)": 167
}

data = pd.concat([data, pd.DataFrame([new_row])], ignore_index=True)

data.to_csv("icecream.csv", index=False)

# Plot icecream
plt.figure()
data["Favourite Ice Cream"].value_counts().plot(kind="pie")
plt.title("Favourite Ice Cream Flavours")
plt.xlabel("Ice Cream")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot colours
plt.figure()
data["Favourite Colour"].value_counts().plot(kind="pie", colormap="grey")
plt.title("Favourite Colours")
plt.xlabel("Colour")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot heights
plt.figure()
plt.hist(data["Height (cm)"], bins=10, edgecolor="black")
plt.title("Height Distribution")
plt.xlabel("Height (cm)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()
# Out:
# Your details were added succesfully!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 43
#      41 # Plot heights
#      42 plt.figure()
# ---> 43 plt.hist(data["Height (cm)"], bins=10, edgecolor="black")
#      44 plt.title("Height Distribution")
#      45 plt.xlabel("Height (cm)")
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\pyplot.py:3478, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3453 @_copy_docstring_and_deprecators(Axes.hist)
#    3454 def hist(
#    3455     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3476     BarContainer | Polygon | list[BarContainer | Polygon],
#    3477 ]:
# -> 3478     return gca().hist(
#    3479         x,
#    3480         bins=bins,
#    3481         range=range,
#    3482         density=density,
#    3483         weights=weights,
#    3484         cumulative=cumulative,
#    3485         bottom=bottom,
#    3486         histtype=histtype,
#    3487         align=align,
#    3488         orientation=orientation,
#    3489         rwidth=rwidth,
#    3490         log=log,
#    3491         color=color,
#    3492         label=label,
#    3493         stacked=stacked,
#    3494         **({"data": data} if data is not None else {}),
#    3495         **kwargs,
#    3496     )
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\axes\_axes.py:7053, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7051 if orientation == "vertical":
#    7052     convert_units = self.convert_xunits
# -> 7053     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    7054          *map(convert_units, x[1:])]
#    7055 else:  # horizontal
#    7056     convert_units = self.convert_yunits
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\axes\_base.py:2663, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2661     # Update from data if axis is already set but no unit is set yet.
#    2662     if axis is not None and data is not None and not axis.have_units():
# -> 2663         axis.update_units(data)
#    2664 for axis_name, axis in axis_map.items():
#    2665     # Return if no axis is set.
#    2666     if axis is None:
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File c:\Users\maira\anaconda3\envs\TIL6022-25\Lib\site-packages\matplotlib\_api\__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
