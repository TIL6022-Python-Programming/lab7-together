# %% [markdown]
# # Lab 7: Versioning 3
#
# Before making any changes to these files, please create a new branch to work on and give it the same name as your Github username. This will be used to determine if you have completed the task successfully.
#
# In the file directory there is a file called `icecream.csv`. There are four columns.
# The first column consists of the Github usernames of the people in the class. The next columns are empty and represent the persons favourite ice cream flavour, favourite colour and height in cm. The code below will read this file and produce graphs showing summaries of the class.
#
# Find your username and fill out your row in `icecream.csv`
# To keep the code simple, you may choose between the following:
#
# **Check if you have entered your row correctly by running the plots below.**
#
# As there is only one entry, you will not see much, you can generate a test dataset if you want to see how it looks like.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv("icecream.csv")

# Plot icecream
plt.figure()
data["Favourite Ice Cream"].value_counts().plot(kind="pie")
plt.title("Favourite Ice Cream Flavours")
plt.xlabel("Ice Cream")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot colours
plt.figure()
data["Favourite Colour"].value_counts().plot(kind="pie", colormap="grey")
plt.title("Favourite Colours")
plt.xlabel("Colour")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot heights
plt.figure()
plt.hist(data["Height (cm)"], bins=10, edgecolor="black")
plt.title("Height Distribution")
plt.xlabel("Height (cm)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 19
#      17 # Plot colours
#      18 plt.figure()
# ---> 19 data["Favourite Colour"].value_counts().plot(kind="pie", colormap="grey")
#      20 plt.title("Favourite Colours")
#      21 plt.xlabel("Colour")
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_matplotlib\core.py:452, in MPLPlot.generate(self)
#     450 self._compute_plot_data()
#     451 self._setup_subplots()
# --> 452 self._make_plot()
#     453 self._add_table()
#     454 self._make_legend()
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1815, in PiePlot._make_plot(self)
#    1814 def _make_plot(self):
# -> 1815     colors = self._get_colors(num_colors=len(self.data), color_kwds="colors")
#    1816     self.kwds.setdefault("colors", colors)
#    1818     for i, (label, y) in enumerate(self._iter_data()):
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_matplotlib\core.py:993, in MPLPlot._get_colors(self, num_colors, color_kwds)
#     990 if num_colors is None:
#     991     num_colors = self.nseries
# --> 993 return get_standard_colors(
#     994     num_colors=num_colors,
#     995     colormap=self.colormap,
#     996     color=self.kwds.get(color_kwds),
#     997 )
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_matplotlib\style.py:75, in get_standard_colors(num_colors, colormap, color_type, color)
#      72 if isinstance(color, dict):
#      73     return color
# ---> 75 colors = _derive_colors(
#      76     color=color,
#      77     colormap=colormap,
#      78     color_type=color_type,
#      79     num_colors=num_colors,
#      80 )
#      82 return list(_cycle_colors(colors, num_colors=num_colors))
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_matplotlib\style.py:125, in _derive_colors(color, colormap, color_type, num_colors)
#      92 """
#      93 Derive colors from either `colormap`, `color_type` or `color` inputs.
#      94
#    (...)
#     122     Parameter `color` will override.
#     123 """
#     124 if color is None and colormap is not None:
# --> 125     return _get_colors_from_colormap(colormap, num_colors=num_colors)
#     126 elif color is not None:
#     127     if colormap is not None:
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_matplotlib\style.py:152, in _get_colors_from_colormap(colormap, num_colors)
#     147 def _get_colors_from_colormap(
#     148     colormap: str | Colormap,
#     149     num_colors: int,
#     150 ) -> list[Color]:
#     151     """Get colors from colormap."""
# --> 152     cmap = _get_cmap_instance(colormap)
#     153     return [cmap(num) for num in np.linspace(0, 1, num=num_colors)]
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\pandas\plotting\_matplotlib\style.py:161, in _get_cmap_instance(colormap)
#     159 cmap = colormap
#     160 if mpl_ge_3_6_0():
# --> 161     colormap = mpl.colormaps[colormap]
#     162 else:
#     163     colormap = cm.get_cmap(colormap)
#
# File c:\Users\hinke\anaconda3\anaconda\Lib\site-packages\matplotlib\cm.py:82, in ColormapRegistry.__getitem__(self, item)
#      80     return self._cmaps[item].copy()
#      81 except KeyError:
# ---> 82     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'grey' is not a known colormap name"
